# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen,Request
import logging

# %%
flipcart_url = 'https://www.flipkart.com/search?q=' + "iphone12pro"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

request = Request(url=flipcart_url, headers=headers)
urlclient = urlopen(request)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /workspace/Python-With-Ds/notebooks/Web Scraping/webScraping.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell://fabc14-pythonwithds-i6kcnbudnvz.ws-us106.gitpod.io/workspace/Python-With-Ds/notebooks/Web%20Scraping/webScraping.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> headers = {
#       <a href='vscode-notebook-cell://fabc14-pythonwithds-i6kcnbudnvz.ws-us106.gitpod.io/workspace/Python-With-Ds/notebooks/Web%20Scraping/webScraping.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
#       <a href='vscode-notebook-cell://fabc14-pythonwithds-i6kcnbudnvz.ws-us106.gitpod.io/workspace/Python-With-Ds/notebooks/Web%20Scraping/webScraping.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> }
# ...

# %%
urlclient

# %%
flipcart_page = urlclient.read()

# %%
flipkart_html=bs(flipcart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="origin" name="referrer"/><meta content="AjoCq8Zg5PcXgfl/SoTikc1e/dzQCdxW0fvo8FxmdXtMpTHFSPThDszr2GTn4aDO9n/lpkW3Zv/js+E6AktuqgkAAABveyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IkxvbmdBbmltYXRpb25GcmFtZVRpbWluZyIsImV4cGlyeSI6MTcwOTY4MzE5OSwiaXNTdWJkb21haW4iOnRydWV9" http-equiv="origin-trial"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>iphone12pro - Google Search</title><script nonce="aKQJTYHjQJxsBNSDmhvw_A">(function(){
# ...

# %%
bigbox = flipkart_html.find("div",{"class":"_1AtVbE col-12-12"})

# %%
# flipkar will not allow you to scrape so it's meaningless to make this project you can use google link to verify that
